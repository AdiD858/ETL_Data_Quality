# %%
import pandas as pd

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, when, isnan, countDistinct,sum
import pyspark.sql.functions as F

# %%
spark = SparkSession.builder.appName("LoanDataQuality").getOrCreate()

# %%
df_loans = spark.read.option('header','true').csv("LCloan_raw_data.csv")

# %%
mapping_file = pd.read_csv('new_loans_mapping.csv')

# %%
mapping_file.columns
# Out:
# Index(['column_name', 'Description', 'source_sheet', 'type_status',
#        'column_type', 'is_required', 'actual_column_in_loans',
#        'business_category'],
#       dtype='object')

# %%
required_cols =mapping_file[mapping_file['is_required'] == True]

# %%
required_cols['business_category'].unique()
# Out:
# array(['credit_info', 'dates', 'loan_info', 'financial_metrics',
#        'payment_info', 'other', 'employment_info', 'special_cases'],
#       dtype=object)

# %% [markdown]
# ### Mapping tests functions

# %%
from PySpark_testing import *

# %%
def map_test_functions(business_category, column_type):
    """
    mapping tetsing functions acoording each column.
    
    :param business_category: קטגוריה עסקית (למשל, 'dates', 'financial_metrics', 'loan_info', 'credit_info', 
                              'employment_info', 'special_cases', 'other')
    :param column_type: סוג העמודה (למשל, 'string', 'int', 'double')
    :return: רשימת שמות בדיקות רלוונטיות
    """
    tests = []
    
    # בדיקות כלליות שחלות על כל העמודות
    tests.append('check_nulls')
    tests.append('check_consistency')
    tests.append('dtype_consistency')
    tests.append('count_records')
    
    # בדיקות לפי סוג העמודה
    if column_type in ['int', 'double']:
        tests.append('validate_numeric_range')
        tests.append('validate_sum')
        tests.append('check_duplicates')
    elif column_type == 'string':
        tests.append('validate_allowed_values')
        tests.append('validate_values_length')
    
    # בדיקות שמבוססות על הקטגוריה העסקית
    if business_category == 'dates':
        tests.append('validate_date_format')
        tests.append('validate_date_range')
        tests.append('file_timeliness')
    elif business_category == 'financial_metrics':
        tests.append('moving_average')
    elif business_category == 'loan_info':
        tests.append('check_foreign_key')
    elif business_category == 'credit_info':
        # לדוגמה, ניתן להוסיף בדיקות ספציפיות לאיכות מידע בתחום האשראי
        tests.append('check_duplicates')
    elif business_category == 'special_cases':
        tests.append('duplicated_files_by_name_and_size')
        tests.append('find_duplicate_columns')
    
    # ניתן להוסיף עוד התאמות בהתאם לניסיון ולדרישות העסקיות
    
    # הסרת כפילויות (אם קיימות) והחזרת רשימה ייחודית
    return list(set(tests))

# %%
# דוגמה לשימוש:
# נניח שיש לך DataFrame בשם loans_mapping שמכיל את העמודות 'business_category' ו-'column_type'
mapping_file['test_function'] = mapping_file.apply(
    lambda row: map_test_functions(row['business_category'], row['column_type']),
    axis=1
)

# %%
mapping_file
# Out:
#                              column_name  \
# 0                       amount requested
# 1                       application date
# 2                             loan title
# 3                             risk_score
# 4                   debt-to-income ratio
# ..                                   ...
# 275                sec_app_num_rev_accts
# 276     sec_app_chargeoff_within_12_mths
# 277   sec_app_collections_12_mths_ex_med
# 278  sec_app_mths_since_last_major_derog
# 279                  disbursement_method
#
#                                            Description source_sheet  \
# 0           The total amount requested by the borrower  RejectStats
# 1                 The date which the borrower applied   RejectStats
# 2              The loan title provided by the borrower  RejectStats
# 3    For applications prior to November 5, 2013 the...  RejectStats
# 4    A ratio calculated using the borrower’s total ...  RejectStats
# ..                                                 ...          ...
# 275   Number of revolving accounts at time of appli...  BrowseNotes
# 276   Number of charge-offs within last 12 months a...  BrowseNotes
# 277   Number of collections within last 12 months e...  BrowseNotes
# 278   Months since most recent 90-day or worse rati...  BrowseNotes
# 279  The method by which the borrower receives thei...  BrowseNotes
#
#      type_status column_type  is_required  \
# 0    not_in_file         NaN        False
# 1    not_in_file         NaN        False
# 2    not_in_file         NaN        False
# 3    not_in_file         NaN        False
# 4    not_in_file         NaN        False
# ..           ...         ...          ...
# 275        found         int         True
# 276        found         int         True
# 277        found         int         True
# 278        found         int         True
# 279        found      string         True
#
#                   actual_column_in_loans  business_category  \
# 0                                    NaN  financial_metrics
# 1                                    NaN              dates
# 2                                    NaN          loan_info
# 3                                    NaN          loan_info
# 4                                    NaN          loan_info
# ..                                   ...                ...
# 275                sec_app_num_rev_accts          loan_info
# 276     sec_app_chargeoff_within_12_mths          loan_info
# 277   sec_app_collections_12_mths_ex_med          loan_info
# 278  sec_app_mths_since_last_major_derog          loan_info
# 279                  disbursement_method          loan_info
#
#                                          test_function
# 0    [count_records, check_nulls, dtype_consistency...
# 1    [count_records, check_nulls, validate_date_ran...
# 2    [count_records, check_nulls, check_foreign_key...
# 3    [count_records, check_nulls, check_foreign_key...
# 4    [count_records, check_nulls, check_foreign_key...
# ..                                                 ...
# 275  [validate_sum, count_records, check_duplicates...
# 276  [validate_sum, count_records, check_duplicates...
# 277  [validate_sum, count_records, check_duplicates...
# 278  [validate_sum, count_records, check_duplicates...
# 279  [count_records, validate_values_length, check_...
#
# [280 rows x 9 columns]

# %%
def map_test_types(business_category, column_type):
    tests = []
    
    # general tests (all columns)
    tests.append('stability')
    tests.append('completeness')
    
    #mapping according business category
    if business_category == 'funds':
        if column_type in ['int', 'double']:
            tests.append('uniqueness')
            tests.append('validity')
        else:
            tests.append('validity')
    
    elif business_category == 'dates':
        tests.append('date_format_validation')
        tests.append('timeliness')
    
    elif business_category == 'loan_info':
        tests.append('accuracy')
    
    elif business_category == 'credit_info':
        tests.append('credit_score_consistency')
    
    elif business_category == 'employment_info':
        tests.append('consistency')
    
    elif business_category == 'special_cases':
        tests.append('custom_validation')
    
    elif business_category == 'other':
        tests.append('basic_validation')
    
    
    # לדוגמה, אם העמודה היא מספרית (int/double) נוסיף בדיקות נוספות.
    if column_type in ['int', 'double']:
        tests.append('range_check')
    
    return tests

# %%
mapping_file['test_type'] = mapping_file.apply(
    lambda row: map_test_types(row['business_category'], row['column_type']),
    axis=1
)

# %%
mapping_file
# Out:
#                              column_name  \
# 0                       amount requested
# 1                       application date
# 2                             loan title
# 3                             risk_score
# 4                   debt-to-income ratio
# ..                                   ...
# 275                sec_app_num_rev_accts
# 276     sec_app_chargeoff_within_12_mths
# 277   sec_app_collections_12_mths_ex_med
# 278  sec_app_mths_since_last_major_derog
# 279                  disbursement_method
#
#                                            Description source_sheet  \
# 0           The total amount requested by the borrower  RejectStats
# 1                 The date which the borrower applied   RejectStats
# 2              The loan title provided by the borrower  RejectStats
# 3    For applications prior to November 5, 2013 the...  RejectStats
# 4    A ratio calculated using the borrower’s total ...  RejectStats
# ..                                                 ...          ...
# 275   Number of revolving accounts at time of appli...  BrowseNotes
# 276   Number of charge-offs within last 12 months a...  BrowseNotes
# 277   Number of collections within last 12 months e...  BrowseNotes
# 278   Months since most recent 90-day or worse rati...  BrowseNotes
# 279  The method by which the borrower receives thei...  BrowseNotes
#
#      type_status column_type  is_required  \
# 0    not_in_file         NaN        False
# 1    not_in_file         NaN        False
# 2    not_in_file         NaN        False
# 3    not_in_file         NaN        False
# 4    not_in_file         NaN        False
# ..           ...         ...          ...
# 275        found         int         True
# 276        found         int         True
# 277        found         int         True
# 278        found         int         True
# 279        found      string         True
#
#                   actual_column_in_loans  business_category  \
# 0                                    NaN  financial_metrics
# 1                                    NaN              dates
# 2                                    NaN          loan_info
# 3                                    NaN          loan_info
# 4                                    NaN          loan_info
# ..                                   ...                ...
# 275                sec_app_num_rev_accts          loan_info
# 276     sec_app_chargeoff_within_12_mths          loan_info
# 277   sec_app_collections_12_mths_ex_med          loan_info
# 278  sec_app_mths_since_last_major_derog          loan_info
# 279                  disbursement_method          loan_info
#
#                                          test_function  \
# 0    [count_records, check_nulls, dtype_consistency...
# 1    [count_records, check_nulls, validate_date_ran...
# 2    [count_records, check_nulls, check_foreign_key...
# 3    [count_records, check_nulls, check_foreign_key...
# 4    [count_records, check_nulls, check_foreign_key...
# ..                                                 ...
# 275  [validate_sum, count_records, check_duplicates...
# 276  [validate_sum, count_records, check_duplicates...
# 277  [validate_sum, count_records, check_duplicates...
# 278  [validate_sum, count_records, check_duplicates...
# 279  [count_records, validate_values_length, check_...
#
#                                              test_type
# 0                            [stability, completeness]
# 1    [stability, completeness, date_format_validati...
# 2                  [stability, completeness, accuracy]
# 3                  [stability, completeness, accuracy]
# 4                  [stability, completeness, accuracy]
# ..                                                 ...
# 275   [stability, completeness, accuracy, range_check]
# 276   [stability, completeness, accuracy, range_check]
# 277   [stability, completeness, accuracy, range_check]
# 278   [stability, completeness, accuracy, range_check]
# 279                [stability, completeness, accuracy]
#
# [280 rows x 10 columns]

# %%
#mapping_file.to_csv("full_mapping.csv", index=False, encoding='utf-8')

# %%
focused_mapping = mapping_file.loc[
    mapping_file['is_required'] == True, 
    ['column_name', 'column_type', 'business_category', 'test_function', 'test_type']
]

# %%
#focused_mapping.to_csv('focused_mapping.csv', index=False,encoding='utf-8')

# %%
focused_mapping
# Out:
#                              column_name column_type  business_category  \
# 9                         acc_now_delinq      string        credit_info
# 10                  acc_open_past_24mths         int              dates
# 11                            addr_state      string          loan_info
# 12                              all_util      string        credit_info
# 13                            annual_inc      string  financial_metrics
# ..                                   ...         ...                ...
# 275                sec_app_num_rev_accts         int          loan_info
# 276     sec_app_chargeoff_within_12_mths         int          loan_info
# 277   sec_app_collections_12_mths_ex_med         int          loan_info
# 278  sec_app_mths_since_last_major_derog         int          loan_info
# 279                  disbursement_method      string          loan_info
#
#                                          test_function  \
# 9    [count_records, validate_values_length, check_...
# 10   [validate_sum, count_records, check_duplicates...
# 11   [count_records, validate_values_length, check_...
# 12   [count_records, validate_values_length, check_...
# 13   [count_records, validate_values_length, moving...
# ..                                                 ...
# 275  [validate_sum, count_records, check_duplicates...
# 276  [validate_sum, count_records, check_duplicates...
# 277  [validate_sum, count_records, check_duplicates...
# 278  [validate_sum, count_records, check_duplicates...
# 279  [count_records, validate_values_length, check_...
#
#                                              test_type
# 9    [stability, completeness, credit_score_consist...
# 10   [stability, completeness, date_format_validati...
# 11                 [stability, completeness, accuracy]
# 12   [stability, completeness, credit_score_consist...
# 13                           [stability, completeness]
# ..                                                 ...
# 275   [stability, completeness, accuracy, range_check]
# 276   [stability, completeness, accuracy, range_check]
# 277   [stability, completeness, accuracy, range_check]
# 278   [stability, completeness, accuracy, range_check]
# 279                [stability, completeness, accuracy]
#
# [210 rows x 5 columns]

# %%
filtered_df = focused_mapping[focused_mapping['test_function'].apply(lambda x: 'check_duplicates' in x)]
print(filtered_df['column_name'])
# Out:
# 9                           acc_now_delinq
# 10                    acc_open_past_24mths
# 12                                all_util
# 17                          bc_open_to_buy
# 18                                 bc_util
#                       ...
# 274                    sec_app_open_act_il
# 275                  sec_app_num_rev_accts
# 276       sec_app_chargeoff_within_12_mths
# 277     sec_app_collections_12_mths_ex_med
# 278    sec_app_mths_since_last_major_derog
# Name: column_name, Length: 105, dtype: object

# %% [markdown]
# ### After mapping tests, checking each test working

# %%
check_nulls(df_loans,'sec_app_num_rev_accts')
check_nulls(df_loans,'all_util')
# Out:
# (True, "Column 'all_util' contains 866341 null value(s).")

# %%
count_records(df_loans,58888)
# Out:
# (False,
#  'Num of records in the file: 2260668Mismatch: the DatatFrame has 2260668 records, but 58888 were expected.')

# %%
check_duplicates(df_loans,['sec_app_chargeoff_within_12_mths','bc_open_to_buy'])

# %%
find_duplicate_columns(df_loans)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25684\262832874.py in ?()
# ----> 1 find_duplicate_columns(df_loans)
#
# ~\ETL-Data-Quality-\data\datadict_csvs\PySpark_testing.py in ?(df)
#     141     checksums = {}
#     142     duplicates = {}
#     143
#     144     for col_name in df.columns:
# --> 145         cs = compute_column_checksum(df, col_name)
#     146         if cs in checksums:
#     147             # אם כבר קיימת עמודה עם אותו checksum, נוסיף את השם לרשימה
#     148             duplicates.setdefault(cs, [checksums[cs]]).append(col_name)
#
# ~\ETL-Data-Quality-\data\datadict_csvs\PySpark_testing.py in ?(df, col_name)
#     129     """
#     130    checksum - compute sum of the hash values in each column .
#     131     """
#     132     # comput sum in each column and perform hash
# --> 133     checksum = df.select(F.sum(F.hash(F.col(col_name))).alias("checksum")).collect()[0]["checksum"]
#     134     return checksum
#
# ~\AppData\Roaming\Python\Python312\site-packages\pyspark\sql\utils.py in ?(*args, **kwargs)
#     170             from pyspark.sql.connect import functions
#     171
#     172             return getattr(functions, f.__name__)(*args, **kwargs)
#     173         else:
# --> 174             return f(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pyspark\sql\functions.py in ?(col)
#     219     Column<'x'>
#     220     >>> column('x')
#     221     Column<'x'>
#     222     """
# --> 223     return _invoke_function("col", col)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pyspark\sql\functions.py in ?(name, *args)
#      91     """
#      92     Invokes JVM function identified by name with args
#      93     and wraps the result with :class:`~pyspark.sql.Column`.
#      94     """
# ---> 95     assert SparkContext._active_spark_context is not None
#      96     jf = _get_jvm_function(name, SparkContext._active_spark_context)
#      97     return Column(jf(*args))
#
# AssertionError:

# %%
spark.stop()

# %%
check_consistency(df1, column_1, df2, column_2, key)

# %%
check_foreign_key(df_fk, column_fk, df_ref, ref_column)

# %%
dtype_consistency(df: DataFrame, column_name: str, expected_type: DataType)

# %%
validate_numeric_range(df, column, min_value, max_value)

# %%
 validate_values_length(df,column_name, data_type)

# %%
validate_allowed_values(df: DataFrame, column_name: str, allowed_values: list)

# %%
validate_date_format(df, column, expected_format)

# %%
file_timeliness(file_path, hours_threshold=24)

# %%
 validate_date_range(df, column, duration, time_unit)

# %%
moving_average(df, column, partitioned_column,date_column, tolerance_deviation, window_size):
